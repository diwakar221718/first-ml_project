# %%
# End to End project on ml (On classification problem)

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
print('numpy',np.__version__)
print('pandas',pd.__version__)
print('sklearn',sklearn.__version__)
# Out:
# numpy 2.3.5
# pandas 2.3.3
# sklearn 1.8.0

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]

# %%
x.head()
# Out:
#    cgpa     iq
# 0   6.8  123.0
# 1   5.9  106.0
# 2   5.3  121.0
# 3   7.4  132.0
# 4   5.8  142.0

# %%
y=df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: placement, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 67   5.0  118.0
# 36   5.7  140.0
# 34   4.8  163.0
# 94   4.7   52.0
# 54   6.4  141.0
# ..   ...    ...
# 20   6.6  120.0
# 66   6.9   96.0
# 97   6.7  182.0
# 19   5.2  132.0
# 11   6.9  138.0
#
# [90 rows x 2 columns]

# %%
Y_train
# Out:
# 67    0
# 36    0
# 34    0
# 94    0
# 54    1
#      ..
# 20    1
# 66    1
# 97    1
# 19    0
# 11    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.91196946, -0.17580919],
#        [-0.29748737,  0.38474185],
#        [-1.08753578,  0.97077249],
#        [-1.17531893, -1.85746233],
#        [ 0.31699473,  0.41022145],
#        [ 0.40477789,  0.12994592],
#        [ 1.98487471,  1.09817046],
#        [ 0.93147683,  0.66501738],
#        [-0.91196946, -1.57718681],
#        [ 0.22921158,  0.07898674],
#        [ 0.40477789,  0.89433371],
#        [-0.99975262,  0.66501738],
#        [-0.64861999, -0.27772756],
#        [-0.56083684,  0.35926226],
#        [ 1.28260946,  0.84337453],
#        [-0.56083684, -0.45608471],
#        [-0.82418631, -1.50074803],
#        [-0.20970421,  0.43570104],
#        [-0.99975262,  1.81159906],
#        [ 0.31699473, -0.22676838],
#        [-0.64861999, -0.09937041],
#        [ 0.66812736, -0.04841123],
#        [ 0.05364526, -0.55800309],
#        [-1.26310209,  0.53761941],
#        [-1.17531893, -0.96567657],
#        [ 1.72152524, -1.16951332],
#        [-0.99975262,  0.2318643 ],
#        [ 1.8093084 ,  1.04721127],
#        [ 1.8093084 ,  0.61405819],
#        [ 0.75591052,  0.35926226],
#        [ 0.66812736, -0.32868675],
#        [-0.12192105, -0.48156431],
#        [-1.78980103, -0.63444187],
#        [ 0.40477789, -0.8892378 ],
#        [-0.03413789, -2.03581948],
#        [-1.08753578,  0.41022145],
#        [ 0.84369367,  1.88803784],
#        [-1.08753578,  1.12365005],
#        [-1.17531893, -0.09937041],
#        [-2.22871682,  2.754344  ],
#        [ 1.10704315, -0.22676838],
#        [ 0.84369367, -1.55170721],
#        [ 0.14142842, -0.30320716],
#        [-0.73640315,  0.91981331],
#        [ 0.05364526, -1.11855413],
#        [ 0.05364526, -1.52622762],
#        [-2.40428313,  1.48036435],
#        [-0.56083684, -0.27772756],
#        [ 1.28260946, -1.62814599],
#        [ 0.84369367,  0.35926226],
#        [-0.03413789, -0.02293163],
#        [-0.03413789, -0.58348268],
#        [-0.91196946, -0.8637582 ],
#        [-0.03413789,  0.61405819],
#        [ 1.37039262,  0.07898674],
#        [-1.4386684 , -2.11225826],
#        [-0.29748737,  0.18090511],
#        [-1.08753578, -0.32868675],
#        [ 1.1948263 ,  0.18090511],
#        [ 1.10704315, -0.99115617],
#        [-0.29748737,  0.46118063],
#        [ 1.28260946,  0.12994592],
#        [-0.82418631,  1.3020072 ],
#        [ 0.05364526,  0.18090511],
#        [-0.73640315, -0.8892378 ],
#        [ 1.54595893, -0.27772756],
#        [-0.99975262, -0.12485001],
#        [ 0.22921158,  0.05350715],
#        [ 2.16044103, -0.12485001],
#        [-0.29748737,  1.12365005],
#        [ 0.66812736,  0.41022145],
#        [ 0.05364526,  0.79241534],
#        [ 0.93147683, -1.9593807 ],
#        [ 0.84369367,  1.27652761],
#        [ 0.49256105,  0.33378267],
#        [-0.73640315,  2.52502767],
#        [-0.99975262, -1.62814599],
#        [-1.87758419, -0.40512553],
#        [ 0.5803442 ,  0.74145616],
#        [ 1.37039262, -0.91471739],
#        [ 1.10704315,  0.30830308],
#        [-1.52645156,  1.91351743],
#        [ 0.66812736, -0.8892378 ],
#        [ 0.22921158, -0.55800309],
#        [-0.03413789, -1.50074803],
#        [ 0.49256105, -0.12485001],
#        [ 0.75591052, -0.73636024],
#        [ 0.5803442 ,  1.45488476],
#        [-0.73640315,  0.18090511],
#        [ 0.75591052,  0.33378267]])

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.84369367, -0.32868675],
#        [-0.73640315, -0.37964594],
#        [-1.4386684 ,  0.61405819],
#        [-0.82418631,  0.07898674],
#        [-0.20970421,  1.04721127],
#        [-0.99975262,  0.76693575],
#        [ 0.40477789, -2.23965622],
#        [ 1.10704315, -1.90842152],
#        [-0.56083684,  0.25734389],
#        [-1.78980103, -1.27143169]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
#model training
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=clf.predict(X_test)  #prediction by model

# %%
Y_test    #given prediction in output col.
# Out:
# 29    1
# 92    0
# 88    0
# 86    0
# 85    1
# 76    0
# 82    1
# 77    1
# 49    0
# 68    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,Y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model1.pkl','wb'))

# %%
import pickle

with open("model1.pkl", "rb") as file:
    model = pickle.load(file)

# %%
print(type(model))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
input_value = [[8, 100]]

# %%
prediction = model.predict(input_value)
print("Predicted class:", prediction[0])
# Out:
# Predicted class: 1
